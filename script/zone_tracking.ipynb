# %% [markdown]
# ## Import

# %%
import os
import sys
import argparse
import numpy as np
import supervision as sv
from pathlib import Path
from ultralytics import YOLO
from dotenv import load_dotenv

# %% [markdown]
# ## Path & Env

# %%
# path
current_path = Path(os.getcwd())
sys.path.insert(0, current_path)

# %%
# env
dotenv_path = f"{current_path}/.env"
load_dotenv(dotenv_path=dotenv_path, override=True)
# Out:
# False

# %% [markdown]
# ## Zone Annotator

# %%
frame_width, frame_height = 1280, 720  # Replace with your video's resolution
zone_polygon = np.array([
    [363, 270],
    [1016, 268],
    [1046, 788],
    [432, 757],
])

zone = sv.PolygonZone(
    polygon=zone_polygon
)

# %%
zone_annotator = sv.PolygonZoneAnnotator(
    zone=zone,
    color=sv.Color.WHITE,
    text_color=sv.Color.BLACK,
    thickness=2,
    text_thickness=2,
    text_scale=0.5
)

# %% [markdown]
# ## Model

# %%
model = YOLO("yolov8n.pt")
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()
tracker = sv.ByteTrack()
# Out:
# FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %% [markdown]
# ## Annotation

# %%
def process_frame(frame: np.ndarray, frame_index: int) -> np.ndarray:
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)

    # filter person obj
    person_class_id = 0 
    detections = detections[detections.class_id == person_class_id]

    # ID tracking
    detections = tracker.update_with_detections(detections)

    is_in_zone = zone.trigger(detections=detections)
    detections_in_zone = detections[is_in_zone]

    # label with class name + ID
    labels = []
    for class_id, tracker_id in zip(detections_in_zone.class_id, detections_in_zone.tracker_id):
        class_name = model.model.names[class_id] if class_id is not None else "unknown"
        label = f"{class_name} #{tracker_id}" if tracker_id is not None else class_name
        labels.append(label)

    # draw boxing
    annotated_frame = box_annotator.annotate(
        scene=frame.copy(),
        detections=detections_in_zone
    )

    # draw labels
    annotated_frame = label_annotator.annotate(
        scene=annotated_frame,
        detections=detections_in_zone,
        labels=labels
    )

    # zone annotation
    annotated_frame = zone_annotator.annotate(
        scene=annotated_frame,
        label=f"Count: {zone.current_count}"
    )

    return annotated_frame

# %% [markdown]
# ## Main Process

# %%
def main(source_video_path: str):
    target_video_path = f"{current_path.parent}/result/result_zone_tracking.mp4"
    print(f"Processing video from '{source_video_path}' and saving to '{target_video_path}'...")
    sv.process_video(
        source_path=source_video_path,
        target_path=target_video_path,
        callback=process_frame
    )
    print("Video processing complete.")

# %%
if __name__ == "__main__":
    video_path = f"{current_path.parent}/videos/finance_20251001_1000_1001.mp4"
    main(video_path)
# Out:
# Processing video from '/mnt/batch/tasks/shared/LS_root/mounts/clusters/gpu-8-56-352-16-jh/code/Users/jeremy.heng/opencv_yolo_supervision/videos/finance_20251001_1000_1001.mp4' and saving to '/mnt/batch/tasks/shared/LS_root/mounts/clusters/gpu-8-56-352-16-jh/code/Users/jeremy.heng/opencv_yolo_supervision/result/result_zone_tracking.mp4'...
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 2 laptops, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 tv, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 2 cups, 2 chairs, 1 dining table, 1 laptop, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 tv, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 tv, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 1 tv, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 1 tv, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 2 chairs, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 2 chairs, 1 tv, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bottle, 1 cup,