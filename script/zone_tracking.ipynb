# %% [markdown]
# ## Import

# %%
import os
import sys
import argparse
import numpy as np
import supervision as sv
from pathlib import Path
from ultralytics import YOLO
from dotenv import load_dotenv

# %% [markdown]
# ## Path & Env

# %%
# path
current_path = Path(os.getcwd())
sys.path.insert(0, current_path)

# %%
# env
dotenv_path = f"{current_path}/.env"
load_dotenv(dotenv_path=dotenv_path, override=True)
# Out:
# False

# %% [markdown]
# ## Zone Annotator

# %%
frame_width, frame_height = 1280, 720 
zone_polygon = np.array([
    [363, 270],
    [1016, 268],
    [1046, 788],
    [432, 757],
])

zone = sv.PolygonZone(
    polygon=zone_polygon
)

# %%
zone_annotator = sv.PolygonZoneAnnotator(
    zone=zone,
    color=sv.Color.WHITE,
    text_color=sv.Color.BLACK,
    thickness=2,
    text_thickness=2,
    text_scale=0.5
)

# %% [markdown]
# ## Model

# %%
model = YOLO("yolov8n.pt")
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()
tracker = sv.ByteTrack()
# Out:
# FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %% [markdown]
# ## Frame Processing

# %%
def process_frame(frame: np.ndarray, frame_index: int) -> np.ndarray:
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)

    # filter person obj
    person_class_id = 0 
    detections = detections[detections.class_id == person_class_id]

    # ID tracking
    detections = tracker.update_with_detections(detections)

    # zone tracking
    is_in_zone = zone.trigger(detections=detections)
    detections_in_zone = detections[is_in_zone]

    # get person in zone data
    class_ids = detections_in_zone.class_id
    tracker_ids = detections_in_zone.tracker_id
    xyxys = detections_in_zone.xyxy
    masks = detections_in_zone.mask if detections_in_zone.mask is not None else [None] * len(detections_in_zone)
    frame_data = []
    for class_id, tracker_id, bbox, mask in zip(class_ids, tracker_ids, xyxys, masks):
        info = {
            "frame_index": frame_index,
            "class_id": class_id,
            "class_name": model.model.names[class_id],
            "tracker_id": tracker_id,
            "bbox": bbox,
            "mask": mask
        }
        frame_data.append(info)
    print(f"Total {len(frame_data)} PERSON IN ZONE: {frame_data}")

    # label with class name + ID
    labels = []
    for class_id, tracker_id in zip(detections_in_zone.class_id, detections_in_zone.tracker_id):
        class_name = model.model.names[class_id] if class_id is not None else "unknown"
        label = f"{class_name} #{tracker_id}" if tracker_id is not None else class_name
        labels.append(label)

    # draw boxing
    annotated_frame = box_annotator.annotate(
        scene=frame.copy(),
        detections=detections_in_zone
    )

    # draw labels
    annotated_frame = label_annotator.annotate(
        scene=annotated_frame,
        detections=detections_in_zone,
        labels=labels
    )

    # zone annotation
    annotated_frame = zone_annotator.annotate(
        scene=annotated_frame,
        label=f"Count: {zone.current_count}"
    )

    return annotated_frame

# %% [markdown]
# ## Main Process

# %%
def main(source_video_path: str):
    target_video_path = f"{current_path.parent}/result/result_zone_tracking.mp4"
    print(f"Processing video from '{source_video_path}' and saving to '{target_video_path}'...")
    sv.process_video(
        source_path=source_video_path,
        target_path=target_video_path,
        callback=process_frame
    )
    print("Video processing complete.")

# %%
if __name__ == "__main__":
    video_path = f"{current_path.parent}/videos/finance_20251001_1000_1001.mp4"
    main(video_path)
# Out:
# Processing video from '/mnt/batch/tasks/shared/LS_root/mounts/clusters/gpu-8-56-352-16-jh/code/Users/jeremy.heng/opencv_yolo_supervision/videos/finance_20251001_1000_1001.mp4' and saving to '/mnt/batch/tasks/shared/LS_root/mounts/clusters/gpu-8-56-352-16-jh/code/Users/jeremy.heng/opencv_yolo_supervision/result/result_zone_tracking.mp4'...
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 0, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     700.63,      336.99,      853.11,      531.06], dtype=float32), 'mask': None}, {'frame_index': 0, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.32,      269.22,      975.15,      420.52], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 1, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     700.87,      337.15,      852.84,      531.09], dtype=float32), 'mask': None}, {'frame_index': 1, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.27,      269.24,      975.09,      420.59], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 2, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     701.64,      336.94,      852.93,       531.2], dtype=float32), 'mask': None}, {'frame_index': 2, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.18,      269.15,      975.22,      420.54], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 3, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     701.12,      337.23,      852.21,      531.34], dtype=float32), 'mask': None}, {'frame_index': 3, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.08,      269.06,       975.5,      420.73], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 4, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     701.14,         337,      852.49,      530.99], dtype=float32), 'mask': None}, {'frame_index': 4, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.22,      268.81,      975.64,      420.91], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 5, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     700.43,      336.92,      851.85,      530.99], dtype=float32), 'mask': None}, {'frame_index': 5, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     861.44,      268.68,       975.2,      421.09], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 6, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     701.68,      336.83,      852.56,      530.88], dtype=float32), 'mask': None}, {'frame_index': 6, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     861.93,       268.8,       975.5,      421.21], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 7, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     701.99,      336.96,      853.34,      530.44], dtype=float32), 'mask': None}, {'frame_index': 7, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.67,      270.87,      974.74,      421.38], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 8, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.98,      268.88,      975.88,      420.85], dtype=float32), 'mask': None}, {'frame_index': 8, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     702.66,      336.71,      854.33,      530.15], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 9, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.72,      268.79,      976.08,      420.93], dtype=float32), 'mask': None}, {'frame_index': 9, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.18,      336.59,      854.07,      530.12], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 10, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.76,      337.29,      852.77,      530.38], dtype=float32), 'mask': None}, {'frame_index': 10, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.94,      268.78,      976.19,      421.11], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 11, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     702.47,      337.67,      852.78,      530.94], dtype=float32), 'mask': None}, {'frame_index': 11, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.25,      268.91,      976.38,      420.77], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 2 bottles, 1 cup, 2 chairs, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 12, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.15,      337.84,      852.84,      530.87], dtype=float32), 'mask': None}, {'frame_index': 12, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.34,      268.96,      976.56,      420.82], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 2 laptops, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 13, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.68,      337.77,      852.11,       531.2], dtype=float32), 'mask': None}, {'frame_index': 13, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.38,      268.87,      976.43,         421], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 14, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.33,      337.56,      851.23,      531.33], dtype=float32), 'mask': None}, {'frame_index': 14, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.09,      269.05,      977.06,      420.92], dtype=float32), 'mask': None}]
#
# 0: 384x640 2 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 15, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.98,      337.71,      852.72,      531.24], dtype=float32), 'mask': None}, {'frame_index': 15, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.07,       269.1,      976.27,      420.73], dtype=float32), 'mask': None}]
#
# 0: 384x640 2 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 16, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.23,      268.96,      976.79,      420.61], dtype=float32), 'mask': None}, {'frame_index': 16, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.67,      337.89,      854.16,      530.99], dtype=float32), 'mask': None}]
#
# 0: 384x640 2 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 17, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.22,      271.12,      975.66,      420.44], dtype=float32), 'mask': None}, {'frame_index': 17, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.48,      337.72,      855.07,      531.27], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 18, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.63,       269.2,      976.41,      420.87], dtype=float32), 'mask': None}, {'frame_index': 18, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.38,      337.66,       854.7,      531.05], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 19, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      865.6,      269.23,      976.71,      421.02], dtype=float32), 'mask': None}, {'frame_index': 19, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.66,       337.8,      853.83,      530.85], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 20, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.18,      338.03,      852.42,       530.6], dtype=float32), 'mask': None}, {'frame_index': 20, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.34,      269.26,      976.55,      421.14], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 21, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.44,      337.98,      852.05,       530.4], dtype=float32), 'mask': None}, {'frame_index': 21, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.51,      269.07,      976.83,      420.88], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 22, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.42,      337.73,      852.44,      530.17], dtype=float32), 'mask': None}, {'frame_index': 22, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.37,      268.96,       976.8,      420.92], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 23, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.65,      339.27,      850.07,      527.94], dtype=float32), 'mask': None}, {'frame_index': 23, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.87,      269.04,      976.92,      420.87], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 24, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.69,      269.04,      977.09,       420.6], dtype=float32), 'mask': None}, {'frame_index': 24, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.05,      339.43,      850.74,      529.73], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 25, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.23,      269.08,      977.04,      420.35], dtype=float32), 'mask': None}, {'frame_index': 25, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.27,      339.55,      850.74,      529.78], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 26, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.68,      268.83,      976.98,      420.56], dtype=float32), 'mask': None}, {'frame_index': 26, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      703.5,      339.16,      850.01,       528.4], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 27, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     864.14,      268.94,      977.03,      420.29], dtype=float32), 'mask': None}, {'frame_index': 27, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.95,      339.38,      848.04,      528.66], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 28, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.74,      268.91,      976.96,      420.24], dtype=float32), 'mask': None}, {'frame_index': 28, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.38,         339,      848.72,      529.02], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 29, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.51,      339.24,         849,      528.45], dtype=float32), 'mask': None}, {'frame_index': 29, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     861.51,      268.79,      976.58,      420.48], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 30, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      704.9,      337.87,      849.21,      529.42], dtype=float32), 'mask': None}, {'frame_index': 30, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     859.92,      270.29,      977.46,      416.69], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 31, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.73,      337.79,      849.17,      528.96], dtype=float32), 'mask': None}, {'frame_index': 31, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     859.98,      270.23,      977.48,      416.63], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 32, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.85,      339.22,      848.25,       528.1], dtype=float32), 'mask': None}, {'frame_index': 32, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     857.57,      270.16,       977.2,      417.37], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 33, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.64,      339.11,         847,      529.44], dtype=float32), 'mask': None}, {'frame_index': 33, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     859.84,      270.36,      976.89,      418.07], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 34, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.24,      339.14,      847.94,      528.63], dtype=float32), 'mask': None}, {'frame_index': 34, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     859.03,      270.26,      976.98,      417.81], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 35, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.03,      339.24,      847.27,      528.39], dtype=float32), 'mask': None}, {'frame_index': 35, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     861.47,      270.44,       976.8,      417.55], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 36, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.61,      339.52,      847.94,      529.13], dtype=float32), 'mask': None}, {'frame_index': 36, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     859.91,       270.3,      976.25,       417.4], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 1 cup, 2 chairs, 1 dining table, 1 tv, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 37, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     707.32,      339.16,      848.03,      528.72], dtype=float32), 'mask': None}, {'frame_index': 37, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([        860,      270.43,      976.29,      417.42], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 38, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.86,      338.76,      847.95,      528.65], dtype=float32), 'mask': None}, {'frame_index': 38, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     861.17,      270.61,      975.99,      417.28], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 39, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      707.4,       337.2,       848.7,      529.66], dtype=float32), 'mask': None}, {'frame_index': 39, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     860.58,      270.56,      975.93,      417.82], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 40, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.04,      338.12,      847.89,      529.46], dtype=float32), 'mask': None}, {'frame_index': 40, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      855.4,      270.26,      974.82,      418.39], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 41, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.73,      338.06,      847.86,       529.5], dtype=float32), 'mask': None}, {'frame_index': 41, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     852.37,      270.01,      975.17,      418.88], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 tv, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 42, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.91,      337.97,      847.44,       529.4], dtype=float32), 'mask': None}, {'frame_index': 42, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      855.8,      270.17,      975.83,      419.12], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 tv, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 43, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.68,      337.84,      847.64,      529.42], dtype=float32), 'mask': None}, {'frame_index': 43, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     850.21,      269.96,      976.05,      419.44], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 44, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      705.6,      337.69,      847.92,      529.48], dtype=float32), 'mask': None}, {'frame_index': 44, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     854.69,      270.39,      975.95,      419.64], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 45, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      705.7,      337.85,      848.23,      529.47], dtype=float32), 'mask': None}, {'frame_index': 45, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     854.31,      270.29,      976.79,      419.35], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 46, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.14,      337.48,      847.93,      529.38], dtype=float32), 'mask': None}, {'frame_index': 46, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     850.89,      270.39,      977.13,      419.52], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 47, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      704.5,      337.43,      849.01,      528.73], dtype=float32), 'mask': None}, {'frame_index': 47, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     853.11,      270.39,      976.91,      418.28], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 48, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.19,      337.34,      848.31,      529.25], dtype=float32), 'mask': None}, {'frame_index': 48, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     855.03,      270.21,      976.57,      418.14], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 2 bottles, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 49, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     702.86,      337.31,      848.93,      529.23], dtype=float32), 'mask': None}, {'frame_index': 49, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     853.42,      270.25,      976.74,      417.62], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 50, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     853.58,      270.07,      976.67,      417.96], dtype=float32), 'mask': None}, {'frame_index': 50, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     703.73,      337.25,      847.88,      528.71], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 51, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     856.43,       270.2,      977.31,      417.77], dtype=float32), 'mask': None}, {'frame_index': 51, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.14,       337.2,      849.45,      528.79], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 52, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     855.42,      270.11,       977.1,      417.72], dtype=float32), 'mask': None}, {'frame_index': 52, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.32,      337.18,      847.07,      528.72], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 2 cups, 2 chairs, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 53, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     702.74,      336.81,      848.08,      526.38], dtype=float32), 'mask': None}, {'frame_index': 53, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.81,       270.2,      976.69,      420.95], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 54, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     702.35,      337.56,      848.57,      527.98], dtype=float32), 'mask': None}, {'frame_index': 54, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     859.79,      269.89,      978.05,      421.37], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 55, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.52,      337.21,      848.49,      528.46], dtype=float32), 'mask': None}, {'frame_index': 55, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     861.28,      270.02,      978.01,      421.17], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 56, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      705.5,      337.22,      848.44,      527.77], dtype=float32), 'mask': None}, {'frame_index': 56, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.33,      270.09,       978.1,      421.18], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 57, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.15,       337.4,      847.83,      528.05], dtype=float32), 'mask': None}, {'frame_index': 57, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.75,      270.12,      978.17,      420.43], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 2 cups, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 58, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     704.95,      337.11,      847.95,      527.98], dtype=float32), 'mask': None}, {'frame_index': 58, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.41,      270.16,      978.23,      420.39], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 59, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.13,      336.87,      848.81,      528.02], dtype=float32), 'mask': None}, {'frame_index': 59, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([        861,      269.89,         978,      420.56], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 60, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.34,      336.73,      846.73,      528.52], dtype=float32), 'mask': None}, {'frame_index': 60, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     854.13,      269.67,      977.64,      420.88], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 61, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      706.2,      336.76,      846.94,      528.68], dtype=float32), 'mask': None}, {'frame_index': 61, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     852.87,      269.71,      977.86,      420.65], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 62, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.77,      336.51,      847.21,      528.79], dtype=float32), 'mask': None}, {'frame_index': 62, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     856.93,      269.91,      978.06,      420.38], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 63, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.52,      336.48,      846.72,      528.45], dtype=float32), 'mask': None}, {'frame_index': 63, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     857.01,      269.92,      977.82,      420.64], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 64, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.34,      336.45,      846.11,      528.26], dtype=float32), 'mask': None}, {'frame_index': 64, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     859.55,      270.27,      977.65,      420.03], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 65, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.05,         336,       845.7,      527.93], dtype=float32), 'mask': None}, {'frame_index': 65, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     856.58,      270.01,      977.37,      419.76], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 66, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.02,      336.14,      845.49,      527.72], dtype=float32), 'mask': None}, {'frame_index': 66, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     857.74,         270,      977.39,      418.47], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 67, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.63,      335.89,      845.42,      527.72], dtype=float32), 'mask': None}, {'frame_index': 67, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     858.91,      270.07,      977.16,      418.41], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 68, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.08,      336.08,      845.64,      527.74], dtype=float32), 'mask': None}, {'frame_index': 68, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     861.36,      270.45,      977.67,      417.98], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 69, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     705.98,         336,      845.37,      527.65], dtype=float32), 'mask': None}, {'frame_index': 69, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     860.32,      270.33,      977.37,      418.18], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 70, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.75,      336.14,      845.21,      527.53], dtype=float32), 'mask': None}, {'frame_index': 70, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     860.06,      270.19,      977.39,       418.3], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 dining table, 1 laptop, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 71, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      706.5,      336.15,      845.11,         528], dtype=float32), 'mask': None}, {'frame_index': 71, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     854.43,      269.38,      976.62,      418.33], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 72, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.67,      335.96,      844.73,      527.95], dtype=float32), 'mask': None}, {'frame_index': 72, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     856.46,      269.52,      976.57,      417.97], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 73, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     706.77,      335.98,      845.41,       527.8], dtype=float32), 'mask': None}, {'frame_index': 73, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     856.34,      269.57,      976.51,      417.83], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 74, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([      706.7,         336,      845.03,      527.87], dtype=float32), 'mask': None}, {'frame_index': 74, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     856.55,       269.4,      976.74,      418.25], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 75, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     707.07,      336.14,      845.29,      527.69], dtype=float32), 'mask': None}, {'frame_index': 75, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     860.07,      270.41,      977.57,      418.15], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 76, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     707.08,      335.93,      845.67,       527.2], dtype=float32), 'mask': None}, {'frame_index': 76, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      865.1,      272.18,      977.34,      420.27], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 77, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     707.42,      336.45,      846.47,      527.67], dtype=float32), 'mask': None}, {'frame_index': 77, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.32,      271.95,      977.03,       420.3], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 78, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     707.53,      336.26,      846.83,         527], dtype=float32), 'mask': None}, {'frame_index': 78, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.01,      271.11,      977.33,      420.41], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 79, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     707.56,      336.37,      846.31,      527.47], dtype=float32), 'mask': None}, {'frame_index': 79, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.17,      270.74,      977.37,      420.08], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 80, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.83,      271.66,       977.6,      419.76], dtype=float32), 'mask': None}, {'frame_index': 80, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(66), 'bbox': array([     707.42,      336.45,      846.54,      527.18], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ...
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 619, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.58,      337.28,      830.64,      530.37], dtype=float32), 'mask': None}, {'frame_index': 619, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.46,       270.3,      976.23,      414.25], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 620, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.58,      337.33,      830.61,       530.4], dtype=float32), 'mask': None}, {'frame_index': 620, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     862.47,      270.15,       976.4,      414.24], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 621, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.87,      337.91,      830.62,      529.15], dtype=float32), 'mask': None}, {'frame_index': 621, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     866.31,      271.04,      976.52,         415], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 622, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([      705.8,      337.77,      830.79,       529.3], dtype=float32), 'mask': None}, {'frame_index': 622, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     866.52,      271.06,      976.51,      415.12], dtype=float32), 'mask': None}]
#
# 0: 384x640 3 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 623, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.85,      337.72,      830.81,      529.01], dtype=float32), 'mask': None}, {'frame_index': 623, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     866.21,      271.02,      976.71,      414.74], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 624, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.96,      337.74,      830.97,      528.93], dtype=float32), 'mask': None}, {'frame_index': 624, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     865.95,      271.14,      976.73,      414.57], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 3 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 625, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.82,      337.74,      830.86,      528.93], dtype=float32), 'mask': None}, {'frame_index': 625, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     868.15,      272.13,      975.27,      418.42], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 3 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 626, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.95,      337.64,      831.08,      530.39], dtype=float32), 'mask': None}, {'frame_index': 626, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     868.32,      271.88,      975.22,      419.35], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 3 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 627, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     705.98,      337.61,       830.9,      530.41], dtype=float32), 'mask': None}, {'frame_index': 627, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     868.32,      271.85,      975.18,      419.31], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 628, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.01,      337.58,      831.18,      530.49], dtype=float32), 'mask': None}, {'frame_index': 628, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     868.09,      271.88,      975.35,       419.3], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 2 chairs, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 629, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.05,      337.59,      831.14,      530.51], dtype=float32), 'mask': None}, {'frame_index': 629, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     868.07,      271.89,      975.34,      419.09], dtype=float32), 'mask': None}]
#
# 0: 384x640 6 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 630, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.39,      337.64,      831.11,       530.8], dtype=float32), 'mask': None}, {'frame_index': 630, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.99,      271.85,      975.35,      419.14], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 631, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.46,      337.64,      831.18,      530.83], dtype=float32), 'mask': None}, {'frame_index': 631, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.94,      271.75,      975.14,      419.24], dtype=float32), 'mask': None}]
#
# 0: 384x640 6 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 632, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.28,       337.6,      831.01,      531.02], dtype=float32), 'mask': None}, {'frame_index': 632, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     868.03,      271.77,      975.22,      419.18], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 633, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.39,      337.56,       831.3,      531.14], dtype=float32), 'mask': None}, {'frame_index': 633, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.96,      271.68,      975.16,      419.15], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 634, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([      706.3,      337.52,      831.47,      531.13], dtype=float32), 'mask': None}, {'frame_index': 634, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      864.1,      270.82,      976.63,      415.52], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 bottle, 1 cup, 1 chair, 2 laptops, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 635, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.35,      337.56,      831.48,      531.33], dtype=float32), 'mask': None}, {'frame_index': 635, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     863.38,       270.8,      976.64,      415.29], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 2 laptops, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 636, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.29,      337.55,      831.46,      531.45], dtype=float32), 'mask': None}, {'frame_index': 636, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      863.2,      270.77,      976.58,      415.42], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 637, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.15,      337.59,      831.24,      531.13], dtype=float32), 'mask': None}, {'frame_index': 637, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.88,      271.73,      975.24,       418.9], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 638, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.12,      337.59,      831.22,      531.14], dtype=float32), 'mask': None}, {'frame_index': 638, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.84,      271.49,      975.31,      418.93], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 639, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.32,      337.59,      831.22,      531.09], dtype=float32), 'mask': None}, {'frame_index': 639, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.58,      271.43,      975.29,      418.94], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 640, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.65,      337.43,       831.1,      531.29], dtype=float32), 'mask': None}, {'frame_index': 640, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      867.6,      271.42,      975.26,      418.93], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 641, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.73,      337.46,      831.24,      531.25], dtype=float32), 'mask': None}, {'frame_index': 641, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([      867.5,      271.45,      975.27,      418.88], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 642, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.71,      337.45,      831.22,      531.21], dtype=float32), 'mask': None}, {'frame_index': 642, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.67,      271.46,      975.14,      418.92], dtype=float32), 'mask': None}]
#
# 0: 384x640 4 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 643, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.61,      337.26,      831.26,      531.28], dtype=float32), 'mask': None}, {'frame_index': 643, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.66,      271.46,      975.12,      418.97], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 644, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.58,      337.28,      831.29,      531.28], dtype=float32), 'mask': None}, {'frame_index': 644, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.65,      271.47,      975.07,      418.97], dtype=float32), 'mask': None}]
#
# 0: 384x640 5 persons, 1 suitcase, 1 bottle, 1 cup, 1 chair, 1 laptop, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Total 2 PERSON IN ZONE: [{'frame_index': 645, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(86), 'bbox': array([     706.57,      337.25,      831.29,      531.31], dtype=float32), 'mask': None}, {'frame_index': 645, 'class_id': np.int64(0), 'class_name': 'person', 'tracker_id': np.int64(2), 'bbox': array([     867.56,      271.44,      975.04,      418.93], dtype=float32), 'mask': None}]
# Video processing complete.
